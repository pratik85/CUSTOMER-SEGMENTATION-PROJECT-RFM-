# %%
#Data manipulation
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Online Retail.xlsx")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %% [markdown]
# # Attribute Information:
#
# InvoiceNo: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# StockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.
# Description: Product (item) name. Nominal.
# Quantity: The quantities of each product (item) per transaction. Numeric.
# InvoiceDate: Invice Date and time. Numeric, the day and time when each transaction was generated.
# UnitPrice: Unit price. Numeric, Product price per unit in sterling.
# CustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.
# Country: Country name. Nominal, the name of the country where each customer resides.

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df[df['UnitPrice']<0].head()
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df[df['UnitPrice']==0].head()
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 622     536414     22139         NaN        56 2010-12-01 11:52:00        0.0
# 1970    536545     21134         NaN         1 2010-12-01 14:32:00        0.0
# 1971    536546     22145         NaN         1 2010-12-01 14:33:00        0.0
# 1972    536547     37509         NaN         1 2010-12-01 14:33:00        0.0
# 1987    536549    85226A         NaN         1 2010-12-01 14:34:00        0.0
#
#       CustomerID         Country
# 622          NaN  United Kingdom
# 1970         NaN  United Kingdom
# 1971         NaN  United Kingdom
# 1972         NaN  United Kingdom
# 1987         NaN  United Kingdom

# %% [markdown]
# # Quantity & UP having negative values it might that quantity was removed or canclelled but we cant say now we have to do more analysis

# %%
cancelled=df[df['InvoiceNo'].astype(str).str.contains('C')]
cancelled.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
cancelled[cancelled['Quantity']>0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# ### In above the unit price is negative and quanity is also negative by this we mean that 'C' denotes cancelled which is denoted here negative quantity and unit price is also negative

# %%
##percentage of cancelled orders
a=len(cancelled)
b=df['InvoiceNo'].nunique()
c=a/b*100
print('The percentage of cancelled order is:',c)
# Out:
# The percentage of cancelled order is: 35.86100386100386

# %%
df1=df.groupby(['InvoiceNo','CustomerID'],as_index=False)['InvoiceDate'].count()
df2=df1.rename(columns = {'InvoiceDate':'Number of products'})
df2.head()
# Out:
#   InvoiceNo  CustomerID  Number of products
# 0    536365     17850.0                   7
# 1    536366     17850.0                   2
# 2    536367     13047.0                  12
# 3    536368     13047.0                   4
# 4    536369     13047.0                   1

# %%
df['Total_cost']=df['Quantity']*df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total_cost
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
fig.set_size_inches(13, 11.5)
ax=sns.barplot(x='Country', y='Total_cost',data=df,estimator=max,ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=47, ha="right")
plt.show()

# %%
df.groupby('Country').sum().sort_values(by='Total_cost',ascending=False)
# Out:
#                       Quantity     UnitPrice    CustomerID    Total_cost
# Country
# United Kingdom         4263829  2.245715e+06  5.626433e+09  8.187806e+06
# Netherlands             200128  6.492550e+03  3.419054e+07  2.846615e+05
# EIRE                    142637  4.844719e+04  1.103917e+08  2.632768e+05
# Germany                 117448  3.766600e+04  1.200751e+08  2.216982e+05
# France                  110480  4.303199e+04  1.076489e+08  1.974039e+05
# Australia                83653  4.054750e+03  1.569300e+07  1.370773e+05
# Switzerland              30325  6.813690e+03  2.377592e+07  5.638535e+04
# Spain                    26824  1.263345e+04  3.268929e+07  5.477458e+04
# Belgium                  23152  7.540130e+03  2.571829e+07  4.091096e+04
# Sweden                   35637  1.806830e+03  6.790083e+06  3.659591e+04
# Japan                    25218  8.148600e+02  4.567292e+06  3.534062e+04
# Norway                   19247  6.529060e+03  1.350765e+07  3.516346e+04
# ...

# %% [markdown]
# ## Most sales revenue are from U K now we are finding out how many customer are present

# %%
df.customerid=df[df['Country']=='United Kingdom']
df.customerid.describe()
# Out:
# <ipython-input-20-0e5baf4e5ac3>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.customerid=df[df['Country']=='United Kingdom']
#             Quantity      UnitPrice     CustomerID     Total_cost
# count  495478.000000  495478.000000  361878.000000  495478.000000
# mean        8.605486       4.532422   15547.871368      16.525065
# std       227.588756      99.315438    1594.402590     394.839116
# min    -80995.000000  -11062.060000   12346.000000 -168469.600000
# 25%         1.000000       1.250000   14194.000000       3.290000
# 50%         3.000000       2.100000   15514.000000       8.290000
# 75%        10.000000       4.130000   16931.000000      16.630000
# max     80995.000000   38970.000000   18287.000000  168469.600000

# %%
groupedProduct =df.customerid.groupby('StockCode',as_index= False)['Quantity'].sum().sort_values(by='Quantity', ascending=False)
groupedProduct.head(10)
# Out:
#      StockCode  Quantity
# 1068     22197     52928
# 2620     84077     48326
# 3655    85099B     43167
# 3666    85123A     36706
# 2733     84879     33519
# 1451     22616     25307
# 375      21212     24702
# 1049     22178     23242
# 39       17003     22801
# 887      21977     20288

# %% [markdown]
# ## removing out the cancelled and negative transations

# %%
df1= df[(df['UnitPrice'] > 0) & (df['Quantity']>0)]

# %% [markdown]
# ### Drop Duplicate transations

# %%
print("Number of duplicated transactions:", len(df1[df1.duplicated()]))
# Out:
# Number of duplicated transactions: 5226

# %%
df1.drop_duplicates(inplace = True)
# Out:
# <ipython-input-24-b8e706a2be12>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates(inplace = True)

# %%
df2 = df1.dropna(subset=['CustomerID'])

# %%
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total_cost
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %% [markdown]
# # Handelling Dates :

# %% [markdown]
# # # Adding new feture month year hour

# %%
df2['month']=df2['InvoiceDate'].dt.month
df2['year']=df2['InvoiceDate'].dt.year
df2['Weekday']=df2['InvoiceDate'].dt.day_name()
df2['hour'] = df2['InvoiceDate'].dt.hour
df2['month_year'] = pd.to_datetime(df2[['year', 'month']].assign(Day=1))
# Out:
# <ipython-input-27-8cddf5bd809c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['month']=df2['InvoiceDate'].dt.month
# <ipython-input-27-8cddf5bd809c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['year']=df2['InvoiceDate'].dt.year
# <ipython-input-27-8cddf5bd809c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total_cost  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    month  year    Weekday  hour month_year
# 0     12  2010  Wednesday     8 2010-12-01
# ...

# %% [markdown]
# # plotting the dataframe

# %%
plot=pd.DataFrame(df2.groupby(['month_year'])['InvoiceNo'].count()).reset_index()
plot1=pd.DataFrame(df2.groupby(['Weekday'])['InvoiceNo'].count())
plot2=pd.DataFrame(df2.groupby(['hour'])['InvoiceNo'].count()).reset_index()
plot1 = plot1.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Sunday']).reset_index()

# %%
import seaborn as sns

# %%
ax = sns.lineplot(x="month_year", y="InvoiceNo", data = plot)

# %%
ax=sns.barplot(x='Weekday',y='InvoiceNo',data=plot1)

# %%
ax=sns.barplot(x='hour',y='InvoiceNo',data=plot2)

# %% [markdown]
# # selecting only U K customer

# %%
df2['freq'] = df2.groupby('CustomerID')['CustomerID'].transform('count')
# Out:
# <ipython-input-34-49b7465f8982>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['freq'] = df2.groupby('CustomerID')['CustomerID'].transform('count')

# %%
df_uk = df2[df2['Country'] == "United Kingdom"]
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total_cost  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    month  year    Weekday  hour month_year  freq
# 0     12  2010  Wednesday     8 2010-12-01   297
# ...

# %%
print(df_uk['InvoiceDate'].max())
print(df_uk['InvoiceDate'].min())
# Out:
# 2011-12-09 12:49:00
# 2010-12-01 08:26:00

# %% [markdown]
# ### RFM ANALYASIS

# %%
df_uk['Date']=df_uk["InvoiceDate"].dt.date
# Out:
# <ipython-input-37-e390e9685dd8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uk['Date']=df_uk["InvoiceDate"].dt.date

# %%
##Group customer and check last date of purchase

recency_df=df_uk.groupby(by='CustomerID',as_index=False)['Date'].max()
recency_df.columns=['CustomerID','LastPurchaseDate']
recency_df.head()
# Out:
#    CustomerID LastPurchaseDate
# 0     12346.0       2011-01-18
# 1     12747.0       2011-12-07
# 2     12748.0       2011-12-09
# 3     12749.0       2011-12-06
# 4     12820.0       2011-12-06

# %%
import datetime as dt
now = dt.date(2020,12,9)
recency_df['Recency'] = recency_df['LastPurchaseDate'].apply(lambda x: (now - x).days)
recency_df.head()
# Out:
#    CustomerID LastPurchaseDate  Recency
# 0     12346.0       2011-01-18     3613
# 1     12747.0       2011-12-07     3290
# 2     12748.0       2011-12-09     3288
# 3     12749.0       2011-12-06     3291
# 4     12820.0       2011-12-06     3291

# %%
##Dropping last purchase bdate as we dont need it anymore
recency_df.drop('LastPurchaseDate',axis=1,inplace=True)

# %% [markdown]
# # Frequency

# %%
frequency_df=df_uk.groupby(by=['CustomerID'],as_index=False)['InvoiceNo'].count()
frequency_df.columns=['CustomerID','Frequency']
frequency_df.head()
# Out:
#    CustomerID  Frequency
# 0     12346.0          1
# 1     12747.0        103
# 2     12748.0       4412
# 3     12749.0        199
# 4     12820.0         59

# %% [markdown]
# # Monetary

# %%
monetary_df=df_uk.groupby(by='CustomerID',as_index=False).agg({'Total_cost':'sum'})
monetary_df.columns = ['CustomerID','Monetary']
monetary_df.head()
# Out:
#    CustomerID  Monetary
# 0     12346.0  77183.60
# 1     12747.0   4196.01
# 2     12748.0  33053.19
# 3     12749.0   4090.88
# 4     12820.0    942.34

# %% [markdown]
# # MERGING RFM TABLE

# %%
temp_df = recency_df.merge(frequency_df,on='CustomerID')
temp_df.head()
# Out:
#    CustomerID  Recency  Frequency
# 0     12346.0     3613          1
# 1     12747.0     3290        103
# 2     12748.0     3288       4412
# 3     12749.0     3291        199
# 4     12820.0     3291         59

# %%
#merge with monetary dataframe to get a table with the 3 columns
rfm_df = temp_df.merge(monetary_df,on='CustomerID')
#use CustomerID as index
rfm_df.set_index('CustomerID',inplace=True)
#check the head
rfm_df.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0        3613          1  77183.60
# 12747.0        3290        103   4196.01
# 12748.0        3288       4412  33053.19
# 12749.0        3291        199   4090.88
# 12820.0        3291         59    942.34

# %%
#get the 80% of the revenue
pareto_cutoff = rfm_df['Monetary'].sum() * 0.8
print("The 80% of total revenue is: ",round(pareto_cutoff,2))
# Out:
# The 80% of total revenue is:  5828019.72

# %%
customers_rank = rfm_df
# Create a new column that is the rank of the value of coverage in ascending order
customers_rank['Rank'] = customers_rank['Monetary'].rank(ascending=0)
#customers_rank.drop('RevenueRank',axis=1,inplace=True)
customers_rank.head()
# Out:
#             Recency  Frequency  Monetary    Rank
# CustomerID
# 12346.0        3613          1  77183.60     6.0
# 12747.0        3290        103   4196.01   283.0
# 12748.0        3288       4412  33053.19    25.0
# 12749.0        3291        199   4090.88   295.0
# 12820.0        3291         59    942.34  1503.0

# %%
customers_rank.sort_values('Rank',ascending=True)
# Out:
#             Recency  Frequency   Monetary    Rank
# CustomerID
# 18102.0        3288        431  259657.30     1.0
# 17450.0        3296        336  194390.79     2.0
# 16446.0        3288          3  168472.50     3.0
# 17511.0        3290        963   91062.38     4.0
# 16029.0        3326        241   80850.84     5.0
# ...             ...        ...        ...     ...
# 16878.0        3372          3      13.30  3916.0
# 17956.0        3537          1      12.75  3917.0
# 16454.0        3332          2       6.90  3918.0
# 14792.0        3351          2       6.20  3919.0
# 16738.0        3585          1       3.75  3920.0
#
# [3920 rows x 4 columns]

# %%
#get top 20% of the customers
top_20_cutoff = 3920 *20 /100
top_20_cutoff
# Out:
# 784.0

# %%
#sum the monetary values over the customer with rank <=784
revenueByTop20 = customers_rank[customers_rank['Rank'] <= 784]['Monetary'].sum()
revenueByTop20
# Out:
# 5345220.561000001

# %% [markdown]
# # Creating RFM Segment Table

# %%
quantiles = rfm_df.quantile(q=[0.25,0.5,0.75])
quantiles.to_dict()
# Out:
# {'Recency': {0.25: 3305.0, 0.5: 3338.0, 0.75: 3430.0},
#  'Frequency': {0.25: 17.0, 0.5: 40.0, 0.75: 98.0},
#  'Monetary': {0.25: 298.18499999999995,
#   0.5: 644.975,
#   0.75: 1571.2849999999994},
#  'Rank': {0.25: 980.75, 0.5: 1960.5, 0.75: 2940.25}}

# %%
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def FMScore(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4

# %%
rfm_segmentation = rfm_df
rfm_segmentation['R_Quartile'] = rfm_segmentation['Recency'].apply(RScore, args=('Recency',quantiles,))
rfm_segmentation['F_Quartile'] = rfm_segmentation['Frequency'].apply(FMScore, args=('Frequency',quantiles,))
rfm_segmentation['M_Quartile'] = rfm_segmentation['Monetary'].apply(FMScore, args=('Monetary',quantiles,))

# %%
rfm_segmentation.head()
# Out:
#             Recency  Frequency  Monetary    Rank  R_Quartile  F_Quartile  \
# CustomerID
# 12346.0        3613          1  77183.60     6.0           1           1
# 12747.0        3290        103   4196.01   283.0           4           4
# 12748.0        3288       4412  33053.19    25.0           4           4
# 12749.0        3291        199   4090.88   295.0           4           4
# 12820.0        3291         59    942.34  1503.0           4           3
#
#             M_Quartile
# CustomerID
# 12346.0              4
# 12747.0              4
# 12748.0              4
# 12749.0              4
# 12820.0              3

# %%
rfm_segmentation['RFMScore'] = rfm_segmentation.R_Quartile.map(str) \
                            + rfm_segmentation.F_Quartile.map(str) \
                            + rfm_segmentation.M_Quartile.map(str)
rfm_segmentation.head()
# Out:
#             Recency  Frequency  Monetary    Rank  R_Quartile  F_Quartile  \
# CustomerID
# 12346.0        3613          1  77183.60     6.0           1           1
# 12747.0        3290        103   4196.01   283.0           4           4
# 12748.0        3288       4412  33053.19    25.0           4           4
# 12749.0        3291        199   4090.88   295.0           4           4
# 12820.0        3291         59    942.34  1503.0           4           3
#
#             M_Quartile RFMScore
# CustomerID
# 12346.0              4      114
# 12747.0              4      444
# 12748.0              4      444
# 12749.0              4      444
# 12820.0              3      433

# %%
rfm_segmentation[rfm_segmentation['RFMScore']=='444'].sort_values('Monetary', ascending=False).head(10)
# Out:
#             Recency  Frequency   Monetary  Rank  R_Quartile  F_Quartile  \
# CustomerID
# 18102.0        3288        431  259657.30   1.0           4           4
# 17450.0        3296        336  194390.79   2.0           4           4
# 17511.0        3290        963   91062.38   4.0           4           4
# 16684.0        3292        277   66653.56   7.0           4           4
# 14096.0        3292       5111   65164.79   8.0           4           4
# 13694.0        3291        568   65039.62   9.0           4           4
# 15311.0        3288       2366   60632.75  10.0           4           4
# 13089.0        3290       1814   58762.08  11.0           4           4
# 15769.0        3295        130   56252.72  13.0           4           4
# 15061.0        3291        403   54534.14  14.0           4           4
#
#             M_Quartile RFMScore
# CustomerID
# 18102.0              4      444
# 17450.0              4      444
# 17511.0              4      444
# ...

# %% [markdown]
# # Applying GMM

# %%
rfm_data = rfm_df.drop(['R_Quartile','F_Quartile','M_Quartile','RFMScore','Rank'],axis=1)
rfm_data.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0        3613          1  77183.60
# 12747.0        3290        103   4196.01
# 12748.0        3288       4412  33053.19
# 12749.0        3291        199   4090.88
# 12820.0        3291         59    942.34

# %%
rfm_data.corr()
# Out:
#             Recency  Frequency  Monetary
# Recency    1.000000  -0.212844 -0.129176
# Frequency -0.212844   1.000000  0.329643
# Monetary  -0.129176   0.329643  1.000000

# %%
# Produce a scatter matrix for each pair of features in the data
from pandas.plotting import scatter_matrix
scatter_matrix(rfm_data, alpha = 0.3, figsize = (11,5), diagonal = 'kde');

# %%
#log transformation
rfm_r_log = np.log(rfm_data['Recency']+0.1) #can't take log(0) and so add a small number
rfm_f_log = np.log(rfm_data['Frequency'])
rfm_m_log = np.log(rfm_data['Monetary']+0.1)

# %%
log_data = pd.DataFrame({'Monetary': rfm_m_log,'Recency': rfm_r_log,'Frequency': rfm_f_log})

# %%
log_data.head()
# Out:
#              Monetary   Recency  Frequency
# CustomerID
# 12346.0     11.253944  8.192321   0.000000
# 12747.0      8.341913  8.098673   4.634729
# 12748.0     10.405876  8.098065   8.392083
# 12749.0      8.316540  8.098977   5.293305
# 12820.0      6.848472  8.098977   4.077537

# %%
# Produce a scatter matrix for each pair of features in the data
scatter_matrix(log_data, alpha = 0.2, figsize = (11,5), diagonal = 'kde');

# %%
from sklearn.mixture import GaussianMixture
gmm =GaussianMixture(n_components=2).fit(matrix)
labels = gmm.predict(matrix)
plt.scatter(matrix[:, 0], matrix[:, 1], c=labels, s=20, cmap='viridis');

# %% [markdown]
# # # K-means

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
matrix = log_data.values
for n_clusters in range(2,10):
    kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=100)
    kmeans.fit(matrix)
    clusters = kmeans.predict(matrix)
    silhouette_avg = silhouette_score(matrix, clusters)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.4776100506397617
# For n_clusters = 3 The average silhouette_score is : 0.4067538343517169
# For n_clusters = 4 The average silhouette_score is : 0.3699971569173673
# For n_clusters = 5 The average silhouette_score is : 0.34120222107780385
# For n_clusters = 6 The average silhouette_score is : 0.35601428294971477
# For n_clusters = 7 The average silhouette_score is : 0.34210945913943874
# For n_clusters = 8 The average silhouette_score is : 0.34907382412364796
# For n_clusters = 9 The average silhouette_score is : 0.3361670530521909

# %%
n_clusters = 2
kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=30)
kmeans.fit(matrix)
clusters_customers = kmeans.predict(matrix)
silhouette_avg = silhouette_score(matrix, clusters_customers)
print('score de silhouette: {:<.3f}'.format(silhouette_avg))
# Out:
# score de silhouette: 0.478

# %%
#create a scatter plot
plt.scatter(matrix[:, 0], matrix[:, 1], c=clusters_customers, s=50, cmap='viridis')
#select cluster centers
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
